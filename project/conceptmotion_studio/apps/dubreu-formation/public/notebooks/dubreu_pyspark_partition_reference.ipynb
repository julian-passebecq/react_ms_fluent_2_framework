# %% [markdown]
# # Understand partition movement
# This lesson explains why a wide transformation may redistribute records. The website displays and explains this source; it does not start Spark.

# %%
from pyspark.sql import functions as F

orders_by_customer = (
    orders.groupBy("customer_id")
          .agg(F.sum("amount").alias("total_amount"))
)
# Out:
# Reference output saved with the source notebook: 4 target partitions

# %% [markdown]
# > **Display-only:** copy or download the code, then use an explicitly configured external runtime when execution is required. Saved output is source evidence, not a fresh run.
