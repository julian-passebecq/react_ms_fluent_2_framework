# %% [markdown]
# # Filter rows with `WHERE`
# Use a predicate to retain only the rows that answer the question. This compact notebook is an original deterministic fixture; it is not the private Dubreu curriculum.

# %%
# Deepnote wrapper retained only as import provenance
_dntk.execute_sql(
    '''SELECT product_id, category, active
       FROM products
       WHERE category = 'notebook' AND active = TRUE
       ORDER BY product_id''',
    'SQL_DEEPNOTE_DATAFRAME_SQL',
    audit_context={'lesson': "where"}
)
# Out:
#  product_id  category  active
#         101  notebook    True
#         104  notebook    True

# %% [markdown]
# ## Try it
# Return active products priced below 50. Keep the stable product identifier in the result.

# %%
SELECT product_id, product_name, price
FROM products
WHERE -- add both predicates
